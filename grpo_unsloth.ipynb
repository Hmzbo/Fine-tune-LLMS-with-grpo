# %% [markdown]
# # Fast Fine-tuning of LLMs with GRPO using Unsloth
#
# Unsloth notebooks [link](https://docs.unsloth.ai/get-started/unsloth-notebooks)

# %% [markdown]
# ## Environement set-up (Windows)
#
# Setting up the environment for this notebook depends heavily on you PC configuration:
#
# First, Unsloth only supports `python=3.10, 3.11, 3.12`
# Then the environment setup is different depending on whether you have conda or not (refer to [unsloth docs](https://docs.unsloth.ai/get-started/installing-+-updating)).
# 1. You need to download the CUDA Toolkit version that is supported by your GPU.
# 2. Based on the cuda version you have, you need then to install the required libraries with the correct versions.
#
# **Note:** If you're on windows and you want to use vLLM for fast inference. You need then to work with WSL and you can then follow the Linux installation from the [unsloth docs](https://docs.unsloth.ai/get-started/installing-+-updating).
#
#
# If your GPU supports CUDA v 12.4, then you can clone my conda enironment, either from the .yaml file or by copying the following commands.
#
# ```
# conda create --name unsloth_env  python=3.11
# pip install torch==2.5.1 torchvision --index-url https://download.pytorch.org/whl/cu124
# pip install -U xformers==0.0.28.post3 --index-url https://download.pytorch.org/whl/cu124
# pip install https://github.com/woct0rdho/triton-windows/releases/download/v3.1.0-windows.post9/triton-3.1.0-cp311-cp311-win_amd64.whl
# pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# pip install --no-deps peft accelerate bitsandbytes
# pip install git+https://github.com/huggingface/trl.git@e95f9fb74a3c3647b86f251b7e230ec51c64b72b
# pip install diffusers[torch] transformers
# ```

# %% [markdown]
# ## Preparing Data and Model for training

# %% [markdown]
# ### Setup Weights and Biases connection to monitor training

# %%
import os
import wandb
from dotenv import load_dotenv

# %%
load_dotenv()
wandb_key = os.getenv("WANDB_KEY")

# %%
wandb.login(key=wandb_key)
wandb.init(project="training_grpo_locally")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\mlwit\_netrc
# wandb: Currently logged in as: hmzbo (hmzbo-vektrai) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>d:\Work\Machine Learning\Projects\NLP\GRPO\wandb\run-20250213_050200-84ug63z2</code>
# Syncing run <strong><a href='https://wandb.ai/hmzbo-vektrai/training_grpo_locally/runs/84ug63z2' target="_blank">ancient-armadillo-6</a></strong> to <a href='https://wandb.ai/hmzbo-vektrai/training_grpo_locally' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hmzbo-vektrai/training_grpo_locally' target="_blank">https://wandb.ai/hmzbo-vektrai/training_grpo_locally</a>
#  View run at <a href='https://wandb.ai/hmzbo-vektrai/training_grpo_locally/runs/84ug63z2' target="_blank">https://wandb.ai/hmzbo-vektrai/training_grpo_locally/runs/84ug63z2</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/hmzbo-vektrai/training_grpo_locally/runs/84ug63z2?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ### Download the base model and setup the lora config

# %%
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "0"  # use to avoid issues when downloading the model from the hub

# %%
from unsloth import FastLanguageModel, PatchFastRL
PatchFastRL("GRPO", FastLanguageModel)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
import torch
max_seq_length = 512 # Can increase for longer reasoning traces
lora_rank = 64 # Larger rank = smarter, but slower (Suggested 8, 16, 32, 64, 128)

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen2.5-3B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = False, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank,
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# ==((====))==  Unsloth 2025.2.4: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA GeForce RTX 3060 Laptop GPU. Max memory: 6.0 GB. Platform: Windows.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# c:\Users\mlwit\.conda\envs\unsloth_env\Lib\site-packages\unsloth\models\llama.py:1243: UserWarning: expandable_segments not supported on this platform (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10/cuda/CUDAAllocatorConfig.h:28.)
#   self.register_buffer("cos_cached", emb.cos().to(dtype=dtype, device=device, non_blocking=True), persistent=False)
# Unsloth 2025.2.4 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### Get the dataset, and define the reward functions and the training prompt

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

def extract_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# Download GSM8K dataset and preprocess it for the task
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_answer(r) for r in responses]
    #print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    rewards = [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]
    print("correctness_rewards: ", rewards, "\n", "="*10, "\n")
    return rewards

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_answer(r) for r in responses]
    rewards = [0.5 if r.isdigit() else 0.0 for r in extracted_responses]
    print("int_rewards: ", rewards)
    return rewards

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    rewards = [0.5 if match else 0.0 for match in matches]
    print("strict_format_rewards: ", rewards)
    return rewards

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    rewards = [0.5 if match else 0.0 for match in matches]
    print("soft_format_rewards: ", rewards)
    return rewards

def count_tags(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def count_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    rewards = [count_tags(c) for c in contents]
    print("xml_count_rewards: ", rewards)
    return rewards

# %% [markdown]
# ## Training

# %%
from unsloth import is_bfloat16_supported
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = False, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 3, # Decrease if out of memory
    max_prompt_length = 256,
    max_completion_length = 400,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 350,
    save_steps = 150,
    max_grad_norm = 0.1,
    report_to = "wandb", # Can use Weights & Biases
    output_dir = "outputs",
)

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        count_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 1 | Gradient Accumulation steps = 1
# \        /    Total batch size = 1 | Total steps = 350
#  "-____-"     Number of trainable parameters = 119,734,272
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# xml_count_rewards:  [-0.727, 0.125, 0.125]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.0, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
#     <div>
#
#       <progress value='350' max='350' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [350/350 3:03:11, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-0.159000</td>
#       <td>0.491902</td>
#       <td>382.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>-0.301000</td>
#       <td>0.101533</td>
#       <td>239.666672</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.230333</td>
#       <td>0.272979</td>
#       <td>225.333344</td>
#       <td>0.000368</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-0.885000</td>
#       <td>0.123746</td>
#       <td>364.666687</td>
#       <td>0.001245</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-0.640000</td>
#       <td>0.077078</td>
#       <td>337.333344</td>
#       <td>0.000415</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-0.269667</td>
#       <td>0.202880</td>
#       <td>205.666672</td>
#       <td>0.000494</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-0.331667</td>
#       <td>0.178500</td>
#       <td>202.000000</td>
#       <td>0.000690</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-0.268667</td>
#       <td>0.162802</td>
#       <td>227.000000</td>
#       <td>0.000959</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-0.064667</td>
#       <td>0.102163</td>
#       <td>158.333344</td>
#       <td>0.000341</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-0.074000</td>
#       <td>0.100195</td>
#       <td>158.333344</td>
#       <td>0.000669</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.395000</td>
#       <td>0.065962</td>
#       <td>215.666672</td>
#       <td>0.000590</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-0.364000</td>
#       <td>0.326605</td>
#       <td>224.666672</td>
#       <td>0.000399</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-0.752333</td>
#       <td>0.117959</td>
#       <td>366.666687</td>
#       <td>0.000467</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-0.249667</td>
#       <td>0.289621</td>
#       <td>213.000000</td>
#       <td>0.000510</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-0.715000</td>
#       <td>0.063663</td>
#       <td>330.000000</td>
#       <td>0.000450</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>-0.476000</td>
#       <td>0.178720</td>
#       <td>234.333344</td>
#       <td>0.000377</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>0.210333</td>
#       <td>1.348722</td>
#       <td>344.333344</td>
#       <td>0.000469</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-0.684333</td>
#       <td>0.203991</td>
#       <td>337.666687</td>
#       <td>0.000633</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.508333</td>
#       <td>1.567425</td>
#       <td>249.666672</td>
#       <td>0.000325</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>-0.446000</td>
#       <td>0.149067</td>
#       <td>247.333344</td>
#       <td>0.000427</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.584667</td>
#       <td>1.515173</td>
#       <td>234.000000</td>
#       <td>0.000308</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.
999999999]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.06, 0.11599999999999999, 0.066]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [-0.20499999999999996, -0.40700000000000003, -0.15800000000000003]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.05199999999999999, 0.07100000000000001, 0.18]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.314, 0.311, 0.311]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.0]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [0.16299999999999998, 0.18, 0.179]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [-0.20299999999999996, 0.066, -0.247]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [0.10199999999999998, 0.07, -0.08599999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 2.0, 0.0]
# xml_count_rewards:  [-0.04200000000000004, 0.05099999999999999, 0.07600000000000001]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [0.5, 0.16499999999999998, 0.132]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.5, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 2.0, 2.0]
# xml_count_rewards:  [0.5, 0.25, -0.21699999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.5, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.0]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [-0.018000000000000016, -0.19000000000000006, 0.396]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [0.07400000000000001, 0.11499999999999999, 0.11699999999999999]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.5, 0.126, 0.11199999999999999]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.21399999999999997, 0.18, 0.10199999999999998]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.136, 0.09599999999999997, 0.5]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 0.0]
# xml_count_rewards:  [0.185, 0.23199999999999998, 0.243]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [-0.028000000000000025, -0.14300000000000002, -0.10299999999999998]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 2.0, 0.0]
# xml_count_rewards:  [0.27, 0.5, 0.5]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.5, 0.5]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.034999999999999976, 0.007000000000000005, 0.068]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [0.23299999999999998, 0.263, 0.269]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.0, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [0.5, 0.237, 0.247]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.5, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.10699999999999998, -0.019000000000000017, -0.256]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [-0.6450000000000001, -0.03500000000000003, 0.0]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [0.14700000000000002, -0.03400000000000003, 0.14700000000000002]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [-0.21399999999999997, -0.06000000000000005, -0.273]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 2.0, 0.0]
# xml_count_rewards:  [0.005000000000000004, -0.7510000000000001, -0.009000000000000008]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [-0.11399999999999999, -0.22599999999999998, -0.347]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [-0.387, 0.125, -0.15800000000000003]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [0.0, 0.0, 2.0]
# xml_count_rewards:  [0.09299999999999997, 0.025999999999999968, -0.09199999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.118, 0.139, 0.017000000000000015]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 0.0, 2.0]
# xml_count_rewards:  [0.0, -0.08899999999999997, 0.022999999999999965]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.0, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [0.5, 0.28200000000000003, 0.5]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.10699999999999998, -0.010000000000000009, 0.261]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.5, 0.22399999999999998, 0.32799999999999996]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.5, 0.0, 0.0]
# int_rewards:  [0.0, 0.0, 0.0]
# ----------
#  correctness_rewards:  [0.0, 0.0, 0.0]
# xml_count_rewards:  [0.184, 0.07900000000000001, -0.273]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.0]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [-0.062000000000000055, -0.353, -0.08299999999999996]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.0]
# ----------
#  correctness_rewards:  [2.0, 2.0, 0.0]
# xml_count_rewards:  [0.23299999999999998, 0.277, 0.31]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.23399999999999999, 0.08599999999999997, 0.15899999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [0.07300000000000001, 0.178, 0.01200000000000001]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [-0.09699999999999998, -0.17100000000000004, -0.245]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.0, 0.0]
# ----------
#  correctness_rewards:  [2.0, 0.0, 0.0]
# xml_count_rewards:  [-0.08499999999999996, 0.025999999999999968, 0.15899999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 2.0]
# xml_count_rewards:  [0.173, 0.16799999999999998, 0.29100000000000004]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# xml_count_rewards:  [-0.11699999999999999, 0.15199999999999997, 0.02999999999999997]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 0.0, 0.0]
# xml_count_rewards:  [-0.265, -0.14300000000000002, 0.5]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.0, 0.5, 0.5]
# ----------
#  correctness_rewards:  [0.0, 2.0, 0.0]
# xml_count_rewards:  [0.13, 0.044999999999999984, 0.05099999999999999]
# soft_format_rewards:  [0.0, 0.0, 0.0]
# strict_format_rewards:  [0.0, 0.0, 0.0]
# int_rewards:  [0.5, 0.5, 0.5]
# ----------
#  correctness_rewards:  [2.0, 2.0, 2.0]
# TrainOutput(global_step=350, training_loss=0.002211461592364462, metrics={'train_runtime': 11050.8236, 'train_samples_per_second': 0.032, 'train_steps_per_second': 0.032, 'total_flos': 0.0, 'train_loss': 0.002211461592364462})

# %%
model.save_pretrained("grpo_saved_lora")

# %% [markdown]
# # Testing

# %% [markdown]
# ### Base Model

# %%
from unsloth import FastLanguageModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
model_ref, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen2.5-3B-Instruct",
    max_seq_length = 512,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = False, # Enable vLLM fast inference
)

model_ref = FastLanguageModel.for_inference(model_ref) 

text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

output = model_ref.generate(
    input_ids=tokenizer(text, return_tensors="pt").input_ids.cuda(),
    temperature=0.8,
    top_p=0.95,
    max_new_tokens=1024,
)

output = tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# ==((====))==  Unsloth 2025.2.4: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA GeForce RTX 3060 Laptop GPU. Max memory: 6.0 GB. Platform: Windows.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# c:\Users\mlwit\.conda\envs\unsloth_env\Lib\site-packages\unsloth\models\llama.py:1243: UserWarning: expandable_segments not supported on this platform (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10/cuda/CUDAAllocatorConfig.h:28.)
#   self.register_buffer("cos_cached", emb.cos().to(dtype=dtype, device=device, non_blocking=True), persistent=False)
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
print(output)
# Out:
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# How many r's are in strawberry?
# assistant
# There are no letters 'r' in the word "strawberry".

# %% [markdown]
# ### Fine-tuned model for reasoning

# %%
from unsloth import FastLanguageModel

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "grpo_saved_lora",
    max_seq_length = 512,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = False, # Enable vLLM fast inference
    max_lora_rank = 64,
)
# Out:
# ==((====))==  Unsloth 2025.2.4: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA GeForce RTX 3060 Laptop GPU. Max memory: 6.0 GB. Platform: Windows.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# c:\Users\mlwit\.conda\envs\unsloth_env\Lib\site-packages\unsloth\models\llama.py:1243: UserWarning: expandable_segments not supported on this platform (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10/cuda/CUDAAllocatorConfig.h:28.)
#   self.register_buffer("cos_cached", emb.cos().to(dtype=dtype, device=device, non_blocking=True), persistent=False)
# Unsloth 2025.2.4 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
model = FastLanguageModel.for_inference(model)

# %%
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

output = model.generate(
    input_ids=tokenizer(text, return_tensors="pt").input_ids.cuda(),
    temperature=0.8,
    top_p=0.95,
    max_new_tokens=1024,
    do_sample=True,
)

output = tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
print(output)
# Out:
# system
#
# Respond in the following format:
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
#
# user
# How many r's are in strawberry?
# assistant
# <reasoning>
# To determine how many times the letter 'r' appears in the word "strawberry", we can go through each letter of the word and count the occurrences of 'r'. The word "strawberry" has the following letters: s, t, r, a, w, b, r, r, e, y. Counting the occurrences, we find that 'r' appears three times.
# </reasoning>
# <answer>
# 3
# </answer>
